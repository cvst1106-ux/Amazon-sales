# %% [markdown]
# # amazon sales
# ## limpieza del dataset

# %% [markdown]
# ### 1. Importacion de librerias y carga del dataset
# * Se van a cargar las librerias pandas y numpy para el manejo de los datos
# * Se va a cargar el dataset para su limpieza

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("11. Amazon Sales.csv")

# %% [markdown]
# ### 2. Revision incial del dataset
# * Se mostrará un resumen del dataset con df.info
# * Se verán las dimensiones con df.shape
# * Se verá el tipo de dato con df.dtypes
# * Se verán las primeras 10 filas con df.shape

# %%
print(df.info())
print(df.shape)
print(df.dtypes)
display(df.head(10))
# Out:
# (1465, 16)
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
# ...

# %% [markdown]
# ### 3. Eliminación de columnas irrelevantes
# * Se eliminarán las columnas que no aportan al analisis de la investigación

# %%
columnas_a_eliminar = [
    'rating',
    'rating_count',
    'about_product',
    'user_id',
    'user_name',
    'review_id',
    'review_title',
    'review_content',
    'img_link',
    'product_link'
]

df = df.drop(columns=columnas_a_eliminar)
print("Columnas disponibles:")
print(df.columns.tolist())
# Out:
# Columnas disponibles:
# ['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage']

# %% [markdown]
# ### 4. limpieza de los datos
#
# * Se identifican los valores nulos del dataset

# %%
print("Valores faltantes por variable:")
nulos = df.isnull().sum()
porcentaje = (nulos / len(df) * 100).round(2)
resumen_nulos = pd.DataFrame({'nulos': nulos, 'porcentaje %': porcentaje})
resumen_nulos[resumen_nulos['nulos'] > 0]
# Out:
# Valores faltantes por variable:
# Empty DataFrame
# Columns: [nulos, porcentaje %]
# Index: []

# %% [markdown]
# * Se detectan y se eliminan las filas duplicadas

# %%
print('Filas duplicadas:', df.duplicated().sum())
df = df.drop_duplicates()
print('Filas tras eliminar duplicados:', df.shape[0])
# Out:
# Filas duplicadas: 110
# Filas tras eliminar duplicados: 1355

# %% [markdown]
# * Se eliminan los simbolos de "₹"y de ","  de `actual_price` y de `discounted_price` para convertirlas a tipo numerico
# * Se eliminan los simbolos de "%"y de ","  de `discount_percentage` para convertirlo a tipo numerico

# %%
df["discounted_price"] = df["discounted_price"].str.replace("₹","" ).str.replace(",", "").astype(float)
df["actual_price"] = df["actual_price"].str.replace("₹","" ).str.replace(",", "").astype(float)
df["discount_percentage"] = df["discount_percentage"].str.replace("%","" ).str.replace(",", "").astype(float)

print(df[['actual_price', 'discounted_price', 'discount_percentage']].head() )
# Out:
#    actual_price  discounted_price  discount_percentage
# 0        1099.0             399.0                 64.0
# 1         349.0             199.0                 43.0
# 2        1899.0             199.0                 90.0
# 3         699.0             329.0                 53.0
# 4         399.0             154.0                 61.0

# %% [markdown]
# * Se recalcula el porcentaje de descuento real con los precios ya limpios

# %%
df["real_discount"] = ((df["actual_price"] - df["discounted_price"]) / df["actual_price"] * 100).round(2)
df["discount_percentage"] = df["real_discount"]
df = df.drop(columns=["real_discount"])

# %% [markdown]
# * Se divide la columna `category` por el símbolo "|" para saber como se estructura la columna

# %%
df["category"].str.split("|")
# Out:
# 0       [Computers&Accessories, Accessories&Peripheral...
# 1       [Computers&Accessories, Accessories&Peripheral...
# 2       [Computers&Accessories, Accessories&Peripheral...
# 3       [Computers&Accessories, Accessories&Peripheral...
# 4       [Computers&Accessories, Accessories&Peripheral...
#                               ...
# 1460    [Home&Kitchen, Kitchen&HomeAppliances, WaterPu...
# 1461    [Home&Kitchen, Kitchen&HomeAppliances, SmallKi...
# 1462    [Home&Kitchen, Heating,Cooling&AirQuality, Roo...
# 1463    [Home&Kitchen, Heating,Cooling&AirQuality, Fan...
# 1464    [Home&Kitchen, Kitchen&HomeAppliances, SmallKi...
# Name: category, Length: 1355, dtype: object

# %% [markdown]
# * Se calculan los cuartiles y el rango intercuartilico para identificar  los datos atipicos

# %%
columnas_numericas = ["actual_price", "discounted_price", "discount_percentage"]

for col in columnas_numericas:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    limite_inf = Q1 - 1.5 * IQR
    limite_sup = Q3 + 1.5 * IQR
    
    outliers = df[(df[col] < limite_inf) | (df[col] > limite_sup)]
    
    print(col + ":", len(outliers), "outliers")
# Out:
# actual_price: 185 outliers
# discounted_price: 210 outliers
# discount_percentage: 0 outliers

# %% [markdown]
# * Se cambian los nombres de las columnas al español para facilitar su interpretación

# %%
df = df.rename(columns={
    "product_id": "id_producto",
    "product_name": "nombre_producto",
    "category": "categoria",
    "actual_price": "precio_original",
    "discounted_price": "precio_descuento",
    "discount_percentage": "porcentaje_descuento"
})
print(df.columns.tolist())
# Out:
# ['id_producto', 'nombre_producto', 'categoria', 'precio_descuento', 'precio_original', 'porcentaje_descuento']

# %% [markdown]
# ### 5. Revisión final
# * Se hará una revision final del dataset para verificar que este correctamente limpio antes de exportarlo

# %%
print(df.shape)
print(df.dtypes)
print(df.info())
display(df.head(10))
# Out:
# (1355, 6)
# id_producto              object
# nombre_producto          object
# categoria                object
# precio_descuento        float64
# precio_original         float64
# porcentaje_descuento    float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 1355 entries, 0 to 1464
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_producto           1355 non-null   object
#  1   nombre_producto       1355 non-null   object
#  2   categoria             1355 non-null   object
#  3   precio_descuento      1355 non-null   float64
#  4   precio_original       1355 non-null   float64
#  5   porcentaje_descuento  1355 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 74.1+ KB
# None
#   id_producto                                    nombre_producto  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# ...

# %%
df.to_csv("amazon_limpio.csv", index=False)
